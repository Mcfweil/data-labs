# %%
#define Bedroom 2

double_bed = {
    "name": "double bed",
    "type": "furniture",
}

dresser = {
    "name": "dresser",
    "type": "furniture",
}

door_b = {
    "name": "door b",
    "type": "door",
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": "door c",
}
key_d = {
    "name": "key for door d",
    "type": "key",
    "target": "door d",
}

#define living room : 
Dining Table = {
    "name": "key for door b",
    "type": "key",
    "target": "door b",
}
door_c = {
    "name": "key for door b",
    "type": "key",
    "target": "door b",
}
door_d = {
    "name": "key for door b",
    "type": "key",
    
queen_bed = {
    "name": "queen bed",
    "type": "furniture",
}

door_a = {
    "name": "door a",
    "type": "door",
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": "door b",
}

door_b = {
    "name": "key for door b",
    "type": "key",
    "target": "door b",
}

door_c = {
    "name": "door c ",
    "type": "door",
}

bedroom_1 = {
    "name": "bed_room",
    "type": "room",
}

outside = {
  "name": "outside"
}

all_rooms = [bedroom_1, outside]

all_doors = [door_a, door_b, door_c]

#Object relation bedroom 2 = 
object_relations = {
    "bedroom 2": [double_bed, door_a, door_b, door_c],
    "queen bed": [key_b],
    "outside": [door_a, door_b, door_c],
    "door a": [bedroom_1, outside]
}

#Object relation living room = 
object_relations = {
    "living_room": [dining_table, door_c, door_d],
    "door c": [key_b],
    "door d": [door_a, door_b, door_c],
}
